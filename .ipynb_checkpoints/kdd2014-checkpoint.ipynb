# %%
# imports
import itertools
import os
import re
import math
import random
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from sklearn import metrics
from sklearn.linear_model import SGDClassifier

from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier, \
    RandomForestRegressor, RandomForestClassifier
from datetime import date
# %matplotlib inline

# %%
print('loading the data...')
projects = pd.read_csv('./data/projects.csv')
outcomes = pd.read_csv('./data/outcomes.csv')
#donations = pd.read_csv('./data/donations.csv')
#resources = pd.read_csv('./data/resources.csv')
print('complete..')
# Out:
# loading the data...
# complete..

# %%
print (projects.shape, outcomes.shape,donations.shape,resources.shape)
# Out:
# (664098, 35) (619326, 12) (3097989, 21) (3667217, 9)

# %%
df = pd.merge(projects, outcomes, how='left', on='projectid')

# %%
print(df.shape)
# Out:
# (664098, 46)

# %%
# adding labels for the dataframe
df["raw"] = "train"
df["raw"][df["date_posted"]<"2010-04-01"] = "no"
df["raw"][df["date_posted"]>="2013-01-01"] = "val"
df["raw"][df["date_posted"]>="2014-01-01"]= "test"
df = df[df["raw"]!="no"]
df['school_ncesid'].apply(str)
df['school_zip'].apply(str)
# Out:
# /Users/hang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/hang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/hang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0         93662.0
# 1         75243.0
# 2         97017.0
# 3         11226.0
# ...

# %%
resources = pd.read_csv('./data/resources.csv')

# %%
resources['cost'] = resources['item_unit_price']*resources['item_quantity']
resources.head()
# Out:
#                          resourceid                         projectid  \
# 0  8a1c1c45bc30d065061912fd9114fcf3  ffffc4f85b60efc5b52347df489d0238
# 1  015d2c4935c50427964a12dc3f584091  ffffac55ee02a49d1abc87ba6fc61135
# 2  26a02944b2f0c25f9abdeacca3ede3ee  ffff97ed93720407d70a2787475932b0
# 3  7fef1f92cb4447d18d599f69ea27e833  ffff97ed93720407d70a2787475932b0
# 4  8dccf77df25ee615bb1a68b98ba9d861  ffff97ed93720407d70a2787475932b0
#
#    vendorid                   vendor_name project_resource_type  \
# 0     430.0        Woodwind and Brasswind            Technology
# 1      82.0         Best Buy for Business            Technology
# 2     767.0  Lakeshore Learning Materials              Supplies
# 3     767.0  Lakeshore Learning Materials              Supplies
# 4     767.0  Lakeshore Learning Materials              Supplies
#
#                                            item_name item_number  \
# 0                      iPod nano 4th Gen 8GB (Black)  249995.001
# ...

# %%
totalcost = resources[['projectid','cost']].groupby('projectid',as_index=False).aggregate(np.sum)
totalcost
# Out:
#                                projectid     cost
# 0       00001ccc0e81598c4bd86bacb94d7acb  1225.44
# 1       00002bff514104264a6b798356fdd893   399.74
# 2       00002d691c05c51a5fdfbb2baef0ba25   774.80
# 3       0000b38bbc7252972f7984848cf58098   444.51
# 4       0000ee613c92ddc5298bf63142996a5c   337.79
# 5       0000fa3aa8f6649abab23615b546016d   185.36
# 6       0000fb6aea57099cc5b051acb7f52a9e   347.50
# 7       0001120447a33dd9ffeefa107ed04c43   237.48
# 8       0001146d343ea9452089d0e302496c06   233.97
# 9       0001151477ea5349a0aa64ed1d83f0bc   597.52
# 10      000131ab172291002281c7bcbc23a0b6   527.97
# 11      000134f07d4b30140d63262c871748ff   735.22
# 12      0001465527a44c2db6258ecef4ff73ab   249.95
# 13      00014917b8c23b8170b2c78df4f094c4   232.01
# 14      00014ba2b351fc0573b94828aa742bec   333.75
# 15      000172f669937044911a57d06eafd360   343.08
# 16      00017d99c933cb7888c63abbd807f406   400.00
# 17      0001820eac84ab9cb11659bd1daf2a7d   222.03
# ...

# %%
df = pd.merge(df, totalcost ,how='left',on='projectid')

# %%
donations = pd.read_csv('./data/donations.csv')

# %%
donations['len'] = donations['donation_message'].apply(str).apply(len)
donations
# Out:
#                                donationid                         projectid  \
# 0        431d720bc3dfd75ae445a5eaa0b0638d  ffffac55ee02a49d1abc87ba6fc61135
# 1        fcfedba1c8a0ba77d280cace80a909f6  ffffac55ee02a49d1abc87ba6fc61135
# 2        3fa95d29986aa6f401c6719ced3a3ce7  ffffac55ee02a49d1abc87ba6fc61135
# 3        020ad6bd5e88a35741d23b5e08f8b8e8  ffffac55ee02a49d1abc87ba6fc61135
# 4        4b44b03f304d6425ae94446686f93cd6  ffffac55ee02a49d1abc87ba6fc61135
# 5        9be4b22432cae4c9ad0a8f8b45e23549  ffffac55ee02a49d1abc87ba6fc61135
# 6        d638145f90a23325b721813b2f8ee7c4  ffffac55ee02a49d1abc87ba6fc61135
# 7        b39547f29dfc25fb13c6e9e8d940dc43  ffff97ed93720407d70a2787475932b0
# 8        471e89e99b76bc0a84b4b7f2c1d85abe  ffff97ed93720407d70a2787475932b0
# 9        87f432143e452c459dd13973c31acc3e  ffff97ed93720407d70a2787475932b0
# 10       d5782c7d267baabe13ef24ace63c4c57  ffff97ed93720407d70a2787475932b0
# ...

# %%
outcomes = pd.read_csv('./data/outcomes.csv')

outcomes.columns = ['projectid','is_exciting','onet_rd','fully_funded','al_one_green','great_chat','3mnt_rd','one_nt_100+',
                    'thoughtful_doner','great_messages_proportion',
                   'teacher_referred_count','nt_referred_count']
outcomes.head(20)
# Out:
#                            projectid is_exciting onet_rd fully_funded  \
# 0   ffffc4f85b60efc5b52347df489d0238           f     NaN            f
# 1   ffffac55ee02a49d1abc87ba6fc61135           f       f            t
# 2   ffff97ed93720407d70a2787475932b0           f       f            t
# 3   ffff418bb42fad24347527ad96100f81           f       f            f
# 4   ffff2d9c769c8fb5335e949c615425eb           t       t            t
# 5   fffeebf4827d745aa36b17c2d38d1966           f       f            t
# 6   fffee68353ade53e7692b23098096683           f       f            f
# 7   fffec078a2249c2365f3086a6eac7e4a           f       f            t
# 8   fffeb149cd9b85d802b2500368fd605e           f       f            t
# 9   fffeaae9482c9b72cab5bbd3f061d362           f       f            f
# 10  fffe700e315373fc1014290cf0c12f51           f     NaN            f
# 11  fffe598a41270538eab48432513513ab           f       f            t
# ...

# %%
outcomes[list(outcomes.columns[2:9])] = outcomes[list(outcomes.columns[2:9])].fillna('f')
outcomes[list(outcomes.columns[9:12])] = outcomes[list(outcomes.columns[9:12])].fillna(0)
outcomes
# Out:
#                                projectid is_exciting onet_rd fully_funded  \
# 0       ffffc4f85b60efc5b52347df489d0238           f       f            f
# 1       ffffac55ee02a49d1abc87ba6fc61135           f       f            t
# 2       ffff97ed93720407d70a2787475932b0           f       f            t
# 3       ffff418bb42fad24347527ad96100f81           f       f            f
# 4       ffff2d9c769c8fb5335e949c615425eb           t       t            t
# 5       fffeebf4827d745aa36b17c2d38d1966           f       f            t
# 6       fffee68353ade53e7692b23098096683           f       f            f
# 7       fffec078a2249c2365f3086a6eac7e4a           f       f            t
# 8       fffeb149cd9b85d802b2500368fd605e           f       f            t
# 9       fffeaae9482c9b72cab5bbd3f061d362           f       f            f
# 10      fffe700e315373fc1014290cf0c12f51           f       f            f
# 11      fffe598a41270538eab48432513513ab           f       f            t
# ...

# %%
# Out:
# ['teacher_teach_for_america' 'eligible_double_your_impact_match'
#  'teacher_prefix' 'school_nlns' 'school_metro'
#  'fulfillment_labor_materials' 'school_city' 'school_county'
#  'primary_focus_area' 'secondary_focus_area' 'poverty_level' 'date_posted'
#  'teacher_ny_teaching_fellow' 'total_price_including_optional_support'
#  'resource_type' 'primary_focus_subject'
#  'total_price_excluding_optional_support' 'school_charter' 'school_kipp'
#  'grade_level' 'students_reached' 'school_state'
#  'eligible_almost_home_match' 'secondary_focus_subject' 'school_year_round'
#  'school_zip' 'school_magnet' 'school_charter_ready_promise'
#  'school_district']

# %%
# Out:
#        teacher_teach_for_america eligible_double_your_impact_match  \
# 148979                         f                                 f
# 437277                         f                                 t
# 405458                         f                                 f
# 91352                          f                                 t
# 49606                          f                                 f
#
#        teacher_prefix school_nlns school_metro  fulfillment_labor_materials  \
# 148979           Mrs.           f        urban                         30.0
# 437277           Mrs.           f        urban                         35.0
# 405458            Mr.           f        urban                         35.0
# 91352            Mrs.           f        rural                         30.0
# 49606             Ms.           f     suburban                         30.0
#
#          school_city school_county   primary_focus_area secondary_focus_area  \
# ...

# %%
# Out:
# [[  0.00000000e+00   0.00000000e+00   3.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   6.31900000e+03]
#  [  0.00000000e+00   1.00000000e+00   3.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   3.00000000e+02]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   2.58000000e+02]
#  ...,
#  [  0.00000000e+00   1.00000000e+00   4.00000000e+00 ...,   1.00000000e+00
#     0.00000000e+00   5.61300000e+03]
#  [  0.00000000e+00   0.00000000e+00   4.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   1.59900000e+03]
#  [  0.00000000e+00   0.00000000e+00   3.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   2.73900000e+03]]
